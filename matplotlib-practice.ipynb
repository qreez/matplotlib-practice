# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.plot([1, 2, 3, 4]);

# %%
a = [1, 2, 3, 4, 5, 6]
plt.plot(a);

# %%
X = [1, 2, 3, 4, 5]
y = [11, 22, 33, 45, 90]
plt.plot(X, y);

# %%
fig, ax = plt.subplots()
ax.plot(X, y);

# %%
import matplotlib.pyplot as plt

X = [1, 2, 3, 4, 5]
y = [11, 22, 35, 48, 59]

fig, ax = plt.subplots()
ax.plot(X, y)

ax.set(title='Some title',
      xlabel='X axis',
      ylabel='y axis');

# %%
import numpy as np

# %%
X = np.linspace(0, 100)

# %%
fig, ax = plt.subplots()
ax.scatter(X, X**2);

# %%
fig, ax = plt.subplots()
ax.scatter(X, np.exp(X));

# %%
fig, ax = plt.subplots()
ax.scatter(X, np.sin(X));

# %%
foods = {'oatmeal': 5, 
        'banana': 3,
        'pumpkin': 9}

# %%
fig, ax = plt.subplots()
ax.bar(foods.keys(), foods.values())
ax.set(title='My favorite food',
      ylabel='Price');

# %%
fig, ax = plt.subplots()
ax.barh(list(foods.keys()), list(foods.values()));

# %%
X = np.random.randn(1000)
plt.hist(X);

# %%
X = np.random.random(1000)
plt.hist(X);

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(nrows=2,
                      ncols=2,
                      figsize=(10, 5))
ax[0, 0].plot(X, X/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(list(foods.keys()), list(foods.values()));
ax[1, 1].hist(np.random.randn(1000));

# %%
import pandas as pd

# %%
car_sales = pd.read_csv('Resources/car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,\.]', '')
car_sales
# Out:
# <ipython-input-63-ff2a0abc9b5e>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales['Price'] = car_sales['Price'].str.replace('[\$\,\.]', '')
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales['Price'] = car_sales['Price'].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales['Total Sales'] = car_sales['Price'].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales
# 0  Toyota  White         150043      4   4000         4000
# 1   Honda    Red          87899      4   5000         9000
# 2  Toyota   Blue          32549      3   7000        16000
# 3     BMW  Black          11179      5  22000        38000
# 4  Nissan  White         213095      4   3500        41500
# 5  Toyota  Green          99213      4   4500        46000
# 6   Honda   Blue          45698      4   7500        53500
# 7   Honda   Blue          54738      4   7000        60500
# 8  Toyota  White          60000      4   6250        66750
# 9  Nissan  White          31600      4   9700        76450

# %%
car_sales['Sale Date'] = pd.date_range('3/6/2021', periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales  Sale Date
# 0  Toyota  White         150043      4   4000         4000 2021-03-06
# 1   Honda    Red          87899      4   5000         9000 2021-03-07
# 2  Toyota   Blue          32549      3   7000        16000 2021-03-08
# 3     BMW  Black          11179      5  22000        38000 2021-03-09
# 4  Nissan  White         213095      4   3500        41500 2021-03-10
# 5  Toyota  Green          99213      4   4500        46000 2021-03-11
# 6   Honda   Blue          45698      4   7500        53500 2021-03-12
# 7   Honda   Blue          54738      4   7000        60500 2021-03-13
# 8  Toyota  White          60000      4   6250        66750 2021-03-14
# 9  Nissan  White          31600      4   9700        76450 2021-03-15

# %%
plt.plot(car_sales['Sale Date'], car_sales['Total Sales']);

# %%
car_sales['Price'] = car_sales['Price'].astype(int)
car_sales.plot(x='Odometer (KM)', y='Price', kind='scatter');

# %%
X = np.random.randn(10, 4)
df = pd.DataFrame(X, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0 -0.870778 -0.139180  0.451776 -1.457659
# 1 -0.046767  1.417182  0.247777 -1.118278
# 2 -0.357087  1.162755 -0.873441  0.294075
# 3 -0.728860 -0.528740  0.567329 -0.421709
# 4  0.803184  1.352711  0.333304 -1.342275
# 5 -0.707295  0.764862  0.138651  0.313856
# 6  0.190179  0.148246 -0.840848  0.986982
# 7 -0.747791  0.224669  0.128983  0.541060
# 8 -0.439254 -2.051030  0.268352  1.041664
# 9  0.278672 -1.283409  0.346150  0.134639

# %%
df.plot.bar();

# %%
car_sales.plot(x='Make', y='Odometer (KM)', kind='bar');

# %%
car_sales['Odometer (KM)'].hist();

# %%
car_sales['Price'].hist(bins=20);

# %%
heart_disease = pd.read_csv('Resources/heart-disease.csv')
heart_disease.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
heart_disease['age'].hist(bins=50);

# %%
heart_disease.plot.hist();

# %%
heart_disease.plot.hist(subplots=True);

# %%
heart_disease.plot.hist(figsize=(10, 30), subplots=True);

# %%
over_50 = heart_disease[heart_disease['age'] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-whitegrid')

fig, ax = plt.subplots(figsize=(10, 6),
                      sharex=True)

scatter = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target'],
                     cmap='winter')

ax.set(title='Heart Disease and Cholesterol Levels',
      xlabel='Age',
      ylabel='Cholesterol')

ax.legend(*scatter.legend_elements(), title='Target')

ax.axhline(y=over_50['chol'].mean(),
           linestyle='--',
           color='red');

ax.set_xlim([50, 80]);

# %%
# fig.savefig('Resources/heart-disease-analysis.png')
